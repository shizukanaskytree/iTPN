# %%
import re

class Node:
    def __init__(self, name):
        self.name = name
        self.children = []

    def add_child(self, child):
        # 检查是否存在重复子节点
        for existing_child in self.children:
            if existing_child.name == child.name:
                return
        self.children.append(child)

def parse_log_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    root = Node("root")
    stack = [root]

    for line in lines:
        if not line.strip() or 'call' not in line:
            continue

        indent_level = (line.count('-') // 4)

        # 提取函数名和路径：行号
        match = re.search(r'function (\w+) in (.+:\d+)', line)
        if match:
            function_name = match.group(1)
            path_line = match.group(2)
            line_content = f"{function_name} in {path_line}"
        else:
            continue

        node = Node(line_content)

        while len(stack) > indent_level + 1:
            stack.pop()

        # 检查重复调用
        if not any(child.name == node.name for child in stack[-1].children):
            stack[-1].add_child(node)
            stack.append(node)

    return root

def print_tree(node, prefix=""):
    children = node.children
    for index, child in enumerate(children):
        connector = "└── " if index == len(children) - 1 else "├── "
        print(prefix + connector + child.name)
        if child.children:
            extension = "    " if index == len(children) - 1 else "│   "
            print_tree(child, prefix + extension)

# 读取日志文件并生成树结构
file_path = './logs-run_itpn_pretraining-host_Fairfax4way04RTX4090-pid_2352294-py/tracing-run_itpn_pretraining-20240722_221840.log'
# file_path = 'path_to_log_file.log'  # 替换为日志文件的实际路径
root = parse_log_file(file_path)

# 打印树状结构
print_tree(root)
# Out:
# ├── get_args in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/run_itpn_pretraining.py:109
# └── main in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/run_itpn_pretraining.py:268
#     ├── init_distributed_mode in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:293
#     ├── setup_for_distributed in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:239
#     ├── print in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:246
#     ├── get_rank in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:268
#     ├── is_dist_avail_and_initialized in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:254
#     ├── get_model in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/run_itpn_pretraining.py:242
#     ├── clip_tpn_base_3324_patch16_224 in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:371
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:56
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:123
#     │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:81
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:162
#     │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:81
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:81
#     │   │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:35
#     │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:81
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:182
#     │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:81
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:35
#     │   │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:81
#     │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:35
#     │   ├── _init_weights in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:250
#     │   └── _cfg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:24
#     ├── build_itpn_pretraining_dataset in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:79
#     ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:17
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:82
#     │   ├── _pil_interp in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:52
#     │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:30
#     ├── __repr__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:53
#     │   ├── __repr__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:168
#     │   └── __repr__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:46
#     ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:64
#     ├── get_clip in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/run_itpn_pretraining.py:257
#     ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/create_clip.py:7
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/create_clip.py:41
#     │   ├── load in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/clip.py:95
#     │   ├── _download in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/clip.py:41
#     │   ├── build_model in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:469
#     │   │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:308
#     │   │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:227
#     │   │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:209
#     │   │   │       └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:184
#     │   │   ├── build_attention_mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:392
#     │   │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:209
#     │   │   │   └── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:184
#     │   │   ├── initialize_parameters in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:363
#     │   │   ├── convert_weights in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:445
#     │   │   └── _convert_weights_to_fp16 in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:448
#     │   └── _transform in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/clip.py:80
#     ├── get_world_size in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:262
#     ├── __len__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:68
#     ├── create_optimizer in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/optim_factory.py:111
#     ├── no_weight_decay in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:259
#     ├── get_parameter_groups in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/optim_factory.py:58
#     │   └── print in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:246
#     ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:392
#     ├── cosine_scheduler in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:447
#     ├── auto_load_model in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:518
#     ├── train_one_epoch in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/engine_for_pretraining.py:22
#     ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:116
#     ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:58
#     ├── add_meter in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:149
#     ├── log_every in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:152
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:58
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       └── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │       └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       └── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │       ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       └── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │       ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │       └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │       ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       └── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │       ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       └── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │       ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │       └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │       ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │       ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │       ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │       ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │       └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     ├── update in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:66
#     ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/create_clip.py:31
#     │   ├── get_target in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/create_clip.py:25
#     │   ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/create_clip.py:46
#     │   └── encode_image in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:404
#     │       ├── dtype in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:400
#     │       ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:246
#     │       ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:172
#     │       └── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:215
#     │           ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:202
#     │           ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:172
#     │           ├── attention in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:197
#     │           └── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/clip/model.py:179
#     ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:351
#     │   ├── forward_features_for_pretraining in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:287
#     │   ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:144
#     │   ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:110
#     │   ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:167
#     │   ├── interpolate_pos_encoding in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_pretrain.py:267
#     │   ├── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:54
#     │   └── forward in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/modeling_finetune.py:188
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:395
#     │   └── get_grad_norm_ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:419
#     ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:410
#     ├── state_dict in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:412
#     ├── update in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:120
#     │   ├── __init__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:58
#     │   └── update in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:66
#     ├── log_every in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:175
#     │   ├── update in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:66
#     │   ├── global_avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:94
#     │   ├── __str__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:137
#     │   ├── __str__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:106
#     │   │   ├── median in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:84
#     │   │   ├── avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:89
#     │   │   ├── global_avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:94
#     │   │   ├── max in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:98
#     │   │   └── value in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:102
#     │   ├── median in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:84
#     │   │   ├── avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:89
#     │   │   ├── global_avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:94
#     │   │   ├── max in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:98
#     │   │   └── value in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:102
#     │   ├── avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:89
#     │   │   ├── global_avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:94
#     │   │   ├── max in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:98
#     │   │   └── value in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:102
#     │   ├── max in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:98
#     │   │   └── value in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:102
#     │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:51
#     │   ├── __getitem__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:71
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/itpn_hf_datasets.py:49
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:149
#     │   │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── get_params in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:106
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/transforms.py:165
#     │   │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:79
#     │   │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── get_shape in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:52
#     │   │   ├── _mask in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:55
#     │   │   └── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── __call__ in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/masking_generator.py:92
#     │   ├── value in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:102
#     │   └── print in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:246
#     ├── synchronize_between_processes in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:145
#     │   ├── synchronize_between_processes in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:71
#     │   └── is_dist_avail_and_initialized in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:254
#     └── global_avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:94
#         └── global_avg in /home/xiaofeng.wu/prjs/iTPN/itpn_clip/utils/utils.py:94

# %% [markdown]
# ### only call

# %%
import re

class Node:
    def __init__(self, name):
        self.name = name
        self.children = []
        self.visited = False

    def add_child(self, child):
        # 检查是否存在重复子节点
        for existing_child in self.children:
            if existing_child.name == child.name:
                return
        self.children.append(child)

def parse_log_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    root = Node("root")
    stack = [root]

    for line in lines:
        if not line.strip():
            continue

        indent_level = (line.count('-') // 4)

        # 提取函数名和路径：行号
        call_match = re.search(r'call function (\w+) in (.+:\d+)', line)
        # exit_match = re.search(r'exit function (\w+) in (.+:\d+)', line)

        if call_match:
            function_name = call_match.group(1)
            path_line = call_match.group(2)
            line_content = f"{function_name}, {path_line}"
        # elif exit_match:
        #     function_name = exit_match.group(1)
        #     path_line = exit_match.group(2)
        #     line_content = f"exit {function_name} in {path_line}"
        else:
            continue

        node = Node(line_content)

        while len(stack) > indent_level + 1:
            stack.pop()

        # 检查重复调用
        if not any(child.name == node.name for child in stack[-1].children):
            stack[-1].add_child(node)
            stack.append(node)

    return root

def print_tree(node, prefix=""):
    children = node.children
    for index, child in enumerate(children):
        connector = "└── " if index == len(children) - 1 else "├── "
        print(prefix + connector + child.name)
        if child.children:
            extension = "    " if index == len(children) - 1 else "│   "
            print_tree(child, prefix + extension)

# 读取日志文件并生成树结构
# file_path = './logs-run_itpn_pretraining-host_Fairfax4way04RTX4090-pid_2352294-py/tracing-run_itpn_pretraining-20240722_221840.log'
file_path = '/home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/logs-run_itpn_pretraining-host_Fairfax4way04RTX4090-pid_2774112-py/tracing-run_itpn_pretraining-20240724_064619.log'
root = parse_log_file(file_path)

# 打印树状结构
print_tree(root)
# Out:
# ├── get_args, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/run_itpn_pretraining.py:131
# └── main, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/run_itpn_pretraining.py:316
#     ├── init_distributed_mode, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:291
#     ├── setup_for_distributed, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:237
#     ├── create_ds_config, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:627
#     ├── get_world_size, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:260
#     │   └── is_dist_avail_and_initialized, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:252
#     ├── print, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:244
#     ├── get_rank, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:266
#     ├── is_dist_avail_and_initialized, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:252
#     ├── get_clip, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/run_itpn_pretraining.py:305
#     ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/create_clip.py:7
#     │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/create_clip.py:41
#     │   ├── load, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/clip.py:95
#     │   ├── _download, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/clip.py:41
#     │   ├── build_model, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:469
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:308
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:227
#     │   │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:209
#     │   │   │       └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:184
#     │   │   ├── build_attention_mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:392
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:209
#     │   │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:184
#     │   │   ├── initialize_parameters, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:363
#     │   │   ├── convert_weights, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:445
#     │   │   └── _convert_weights_to_fp16, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:448
#     │   └── _transform, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/clip.py:80
#     ├── get_model, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/run_itpn_pretraining.py:287
#     ├── itpn_base_fusedLN_NaiveSwiGLU_subln_xavier_3324_patch16_224, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:740
#     │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:31
#     │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:538
#     │   ├── build_blocks, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:276
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:423
#     │   │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:85
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:48
#     │   │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:85
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:85
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:602
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:317
#     │   │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:168
#     │   │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:48
#     │   │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:113
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:168
#     │   │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:48
#     │   │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:113
#     │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:113
#     │   ├── build_fpn_blocks, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:428
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:423
#     │   │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:85
#     │   │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:634
#     │   ├── trunc_normal_, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:26
#     │   ├── _xavier_normal_init, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:267
#     │   ├── print, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:244
#     │   └── _cfg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:31
#     ├── build_dataset, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:103
#     ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:30
#     │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:82
#     │   ├── _pil_interp, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:52
#     │   └── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:30
#     ├── __repr__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:78
#     │   ├── __repr__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:168
#     │   └── __repr__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:46
#     ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:89
#     ├── __len__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:93
#     ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:198
#     ├── no_weight_decay, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:594
#     ├── get_parameter_groups, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/optim_factory.py:58
#     ├── extra_repr, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:55
#     ├── cosine_scheduler, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:472
#     ├── auto_load_model, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:543
#     ├── set_step, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:202
#     ├── train_one_epoch, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/engine_for_pretraining.py:77
#     ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:114
#     ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:56
#     ├── add_meter, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:147
#     ├── log_every, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:150
#     │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:56
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │       ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │       ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │       ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   ├── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │       ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │       ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │       ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │       ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── update, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:64
#     ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/create_clip.py:31
#     │   ├── get_target, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/create_clip.py:25
#     │   ├── encode_image, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:404
#     │   │   ├── dtype, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:400
#     │   │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:246
#     │   │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:172
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:215
#     │   │       ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:202
#     │   │       ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:172
#     │   │       ├── attention, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:197
#     │   │       └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:179
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:172
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:179
#     │   │       ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:202
#     │   │       ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:172
#     │   │       ├── attention, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:197
#     │   │       └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/clip/model.py:179
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:666
#     │   ├── forward_features, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_pretrain.py:607
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:561
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:478
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:100
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:100
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:52
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:52
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:608
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:382
#     │   │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:240
#     │   │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:52
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:129
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:240
#     │   │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:52
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:129
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:129
#     │   │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:52
#     │   └── forward, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/modeling_finetune.py:640
#     │       └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     ├── compute_loss, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/engine_for_pretraining.py:36
#     ├── update, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:118
#     │   ├── __init__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:56
#     │   └── update, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:64
#     ├── get_loss_scale_for_deepspeed, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/engine_for_pretraining.py:26
#     ├── update, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:208
#     ├── log_every, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:173
#     │   ├── update, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:64
#     │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   ├── __str__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:135
#     │   ├── __str__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:104
#     │   │   ├── median, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:82
#     │   │   ├── avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:87
#     │   │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── median, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:82
#     │   │   ├── avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:87
#     │   │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:87
#     │   │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __getitem__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:96
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/itpn_hf_datasets.py:72
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:149
#     │   │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── get_params, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/transforms.py:106
#     │   │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── __call__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:79
#     │   │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   ├── get_shape, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:52
#     │   │   └── _mask, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/masking_generator.py:55
#     │   └── print, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:244
#     ├── synchronize_between_processes, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:143
#     │   ├── synchronize_between_processes, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:69
#     │   └── is_dist_avail_and_initialized, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:252
#     ├── __str__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:135
#     │   ├── __str__, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:104
#     │   │   ├── median, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:82
#     │   │   ├── avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:87
#     │   │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── median, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:82
#     │   │   ├── avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:87
#     │   │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:87
#     │   │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── global_avg, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:92
#     │   │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   ├── max, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:96
#     │   │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     │   └── value, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:100
#     ├── save_model, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:492
#     ├── is_main_process, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:272
#     └── flush, /home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/utils/utils.py:223

# %% [markdown]
# ### Study
#
# node, graph, tree.
#
# todo ...

# %%
import re

class Node:
    def __init__(self, name):
        self.name = name
        self.children = []
        self.visited = False

    def add_child(self, child):
        # 检查是否存在重复子节点
        for existing_child in self.children:
            if existing_child.name == child.name:
                return
        self.children.append(child)

def parse_log_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    root = Node("root")
    stack = [root]

    for line in lines:
        if not line.strip():
            continue

        indent_level = (line.count('-') // 4)

        # 提取函数名和路径：行号
        call_match = re.search(r'call function (\w+) in (.+:\d+)', line)
        # exit_match = re.search(r'exit function (\w+) in (.+:\d+)', line)

        if call_match:
            function_name = call_match.group(1)
            path_line = call_match.group(2)
            line_content = f"{function_name}, {path_line}"
        # elif exit_match:
        #     function_name = exit_match.group(1)
        #     path_line = exit_match.group(2)
        #     line_content = f"exit {function_name} in {path_line}"
        else:
            continue

        node = Node(line_content)

        while len(stack) > indent_level + 1:
            stack.pop()

        # 检查重复调用
        if not any(child.name == node.name for child in stack[-1].children):
            stack[-1].add_child(node)
            stack.append(node)

    return root

def print_tree(node, prefix=""):
    children = node.children
    for index, child in enumerate(children):
        connector = "└── " if index == len(children) - 1 else "├── "
        print(prefix + connector + child.name)
        if child.children:
            extension = "    " if index == len(children) - 1 else "│   "
            print_tree(child, prefix + extension)

# 读取日志文件并生成树结构
# file_path = './logs-run_itpn_pretraining-host_Fairfax4way04RTX4090-pid_2352294-py/tracing-run_itpn_pretraining-20240722_221840.log'
file_path = '/home/xiaofeng.wu/prjs/iTPN/CLIP_as_supervision/logs-run_itpn_pretraining-host_Fairfax4way04RTX4090-pid_2774112-py/tracing-run_itpn_pretraining-20240724_064619.log'
root = parse_log_file(file_path)

# 打印树状结构
print_tree(root)
